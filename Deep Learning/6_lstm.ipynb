# %% [markdown]
# Deep Learning
# =============
#
# Assignment 6
# ------------
#
# After training a skip-gram model in `5_word2vec.ipynb`, the goal of this notebook is to train a LSTM character model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
from __future__ import print_function
import os
import numpy as np
import random
import string
import tensorflow as tf
import zipfile
from six.moves import range
from six.moves.urllib.request import urlretrieve
import itertools
import collections

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %%
def read_data(filename):
  with zipfile.ZipFile(filename) as f:
    name = f.namelist()[0]
    data = tf.compat.as_str(f.read(name))
  return data
  
text = read_data(filename)
print('Data size %d' % len(text))
# Out:
# Data size 100000000

# %% [markdown]
# Create a small validation set.

# %%
valid_size = 1000
valid_text = text[:valid_size]
train_text = text[valid_size:]
train_size = len(train_text)
print(train_size, train_text[:64])
print(valid_size, valid_text[:64])
# Out:
# 99999000 ons anarchists advocate social relations based upon voluntary as
# 1000  anarchism originated as a term of abuse first used against earl

# %% [markdown]
# Utility functions to map characters to vocabulary IDs and back.

# %%
vocabulary_size = len(string.ascii_lowercase) + 1 # [a-z] + ' '
first_letter = ord(string.ascii_lowercase[0])

def char2id(char):
  if char in string.ascii_lowercase:
    return ord(char) - first_letter + 1
  elif char == ' ':
    return 0
  else:
    print('Unexpected character: %s' % char)
    return 0
  
def id2char(dictid):
  if dictid > 0:
    return chr(dictid + first_letter - 1)
  else:
    return ' '

print(char2id('a'), char2id('z'), char2id(' '), char2id('ï'))
print(id2char(1), id2char(26), id2char(0))
# Out:
# Unexpected character: ï
# 1 26 0 0
# a z

# %% [markdown]
# Function to generate a training batch for the LSTM model.

# %%
batch_size=64
num_unrollings=10

class BatchGenerator(object):
  def __init__(self, text, batch_size, num_unrollings):
    self._text = text
    self._text_size = len(text)
    self._batch_size = batch_size
    self._num_unrollings = num_unrollings
    segment = self._text_size // batch_size
    self._cursor = [ offset * segment for offset in range(batch_size)]
    self._last_batch = self._next_batch()
  
  def _next_batch(self):
    """Generate a single batch from the current cursor position in the data."""
    batch = np.zeros(shape=(self._batch_size, vocabulary_size), dtype=np.float)
    for b in range(self._batch_size):
      batch[b, char2id(self._text[self._cursor[b]])] = 1.0
      self._cursor[b] = (self._cursor[b] + 1) % self._text_size
    return batch
  
  def next(self):
    """Generate the next array of batches from the data. The array consists of
    the last batch of the previous array, followed by num_unrollings new ones.
    """
    batches = [self._last_batch]
    for step in range(self._num_unrollings):
      batches.append(self._next_batch())
    self._last_batch = batches[-1]
    return batches

def characters(probabilities):
  """Turn a 1-hot encoding or a probability distribution over the possible
  characters back into its (most likely) character representation."""
  return [id2char(c) for c in np.argmax(probabilities, 1)]

def batches2string(batches):
  """Convert a sequence of batches back into their (most likely) string
  representation."""
  s = [''] * batches[0].shape[0]
  for b in batches:
    s = [''.join(x) for x in zip(s, characters(b))]
  return s

train_batches = BatchGenerator(train_text, batch_size, num_unrollings)
valid_batches = BatchGenerator(valid_text, 1, 1)

#print(train_batches.next())
#print(batches2string(train_batches.next()))
#print(valid_batches.next())
print(batches2string(valid_batches.next()))
print(batches2string(valid_batches.next()))
print(batches2string(valid_batches.next()))
# Out:
# [' a']
# ['an']
# ['na']

# %%
def logprob(predictions, labels):
  """Log-probability of the true labels in a predicted batch."""
  predictions[predictions < 1e-10] = 1e-10
  return np.sum(np.multiply(labels, -np.log(predictions))) / labels.shape[0]

def sample_distribution(distribution):
  """Sample one element from a distribution assumed to be an array of normalized
  probabilities.
  """
  r = random.uniform(0, 1)
  s = 0
  for i in range(len(distribution)):
    s += distribution[i]
    if s >= r:
      return i
  return len(distribution) - 1

def sample(prediction):
  """Turn a (column) prediction into 1-hot encoded samples."""
  p = np.zeros(shape=[1, vocabulary_size], dtype=np.float)
  p[0, sample_distribution(prediction[0])] = 1.0
  return p

def random_distribution():
  """Generate a random column of probabilities."""
  b = np.random.uniform(0.0, 1.0, size=[1, vocabulary_size])
  return b/np.sum(b, 1)[:,None]

# %% [markdown]
# Simple LSTM Model.

# %% [markdown]
# ---
# Problem 1
# ---------
#
# You might have noticed that the definition of the LSTM cell involves 4 matrix multiplications with the input, and 4 matrix multiplications with the output. Simplify the expression by using a single matrix multiply for each, and variables that are 4 times larger.

# %%
num_nodes = 64

graph = tf.Graph()
with graph.as_default():
  
  # Parameters:
  # Input gate: input, previous output, and bias.
  #ix = tf.Variable(tf.truncated_normal([vocabulary_size, num_nodes], -0.1, 0.1))
  #im = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
  #ib = tf.Variable(tf.zeros([1, num_nodes]))
  # Forget gate: input, previous output, and bias.
  #fx = tf.Variable(tf.truncated_normal([vocabulary_size, num_nodes], -0.1, 0.1))
  #fm = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
  #fb = tf.Variable(tf.zeros([1, num_nodes]))
  # Memory cell: input, state and bias.                             
  #cx = tf.Variable(tf.truncated_normal([vocabulary_size, num_nodes], -0.1, 0.1))
  #cm = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
  #cb = tf.Variable(tf.zeros([1, num_nodes]))
  # Output gate: input, previous output, and bias.
  #ox = tf.Variable(tf.truncated_normal([vocabulary_size, num_nodes], -0.1, 0.1))
  #om = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
  #ob = tf.Variable(tf.zeros([1, num_nodes]))
  
  #Creating variable 4 times the size to cut down the matrix multiplication
  big_x = tf.Variable(tf.truncated_normal([vocabulary_size, 4*num_nodes], -0.1, 0.1))
  big_m = tf.Variable(tf.truncated_normal([num_nodes, 4*num_nodes], -0.1, 0.1))
  big_b = tf.Variable(tf.zeros([1, 4*num_nodes]))

  # Variables saving state across unrollings.
  saved_output = tf.Variable(tf.zeros([batch_size, num_nodes]), trainable=False)
  saved_state = tf.Variable(tf.zeros([batch_size, num_nodes]), trainable=False)
  # Classifier weights and biases.
  w = tf.Variable(tf.truncated_normal([num_nodes, vocabulary_size], -0.1, 0.1))
  b = tf.Variable(tf.zeros([vocabulary_size]))

  
  # Definition of the cell computation.
  def lstm_cell(i, o, state):
    """Create a LSTM cell. See e.g.: http://arxiv.org/pdf/1402.1128v1.pdf
    Note that in this formulation, we omit the various connections between the
    previous state and the gates."""
    big_matmul = tf.matmul(i, big_x) + tf.matmul(o, big_m) + big_b
    big_input, big_forget, update, big_output = tf.split(big_matmul, num_or_size_splits=4, axis=1)
    input_gate = tf.sigmoid(big_input)
    forget_gate = tf.sigmoid(big_forget)
    #update = tf.matmul(i, cx) + tf.matmul(o, cm) + cb
    state = forget_gate * state + input_gate * tf.tanh(update)
    output_gate = tf.sigmoid(big_output)
    return output_gate * tf.tanh(state), state

  # Input data.
  train_data = list()
  for _ in range(num_unrollings + 1):
    train_data.append(
      tf.placeholder(tf.float32, shape=[batch_size,vocabulary_size]))
  train_inputs = train_data[:num_unrollings]
  train_labels = train_data[1:]  # labels are inputs shifted by one time step.

  # Unrolled LSTM loop.
  outputs = list()
  output = saved_output
  state = saved_state
  for i in train_inputs:
    output, state = lstm_cell(i, output, state)
    outputs.append(output)

  # State saving across unrollings.
  with tf.control_dependencies([saved_output.assign(output),
                                saved_state.assign(state)]):
    # Classifier.
    logits = tf.nn.xw_plus_b(tf.concat(outputs, 0), w, b)
    loss = tf.reduce_mean(
      tf.nn.softmax_cross_entropy_with_logits(
        labels=tf.concat(train_labels, 0), logits=logits))

  # Optimizer.
  global_step = tf.Variable(0)
  learning_rate = tf.train.exponential_decay(
    10.0, global_step, 5000, 0.1, staircase=True)
  optimizer = tf.train.GradientDescentOptimizer(learning_rate)
  gradients, v = zip(*optimizer.compute_gradients(loss))
  gradients, _ = tf.clip_by_global_norm(gradients, 1.25)
  optimizer = optimizer.apply_gradients(
    zip(gradients, v), global_step=global_step)

  # Predictions.
  train_prediction = tf.nn.softmax(logits)
  
  # Sampling and validation eval: batch 1, no unrolling.
  sample_input = tf.placeholder(tf.float32, shape=[1, vocabulary_size])
  saved_sample_output = tf.Variable(tf.zeros([1, num_nodes]))
  saved_sample_state = tf.Variable(tf.zeros([1, num_nodes]))
  reset_sample_state = tf.group(
    saved_sample_output.assign(tf.zeros([1, num_nodes])),
    saved_sample_state.assign(tf.zeros([1, num_nodes])))
  sample_output, sample_state = lstm_cell(
    sample_input, saved_sample_output, saved_sample_state)
  with tf.control_dependencies([saved_sample_output.assign(sample_output),
                                saved_sample_state.assign(sample_state)]):
    sample_prediction = tf.nn.softmax(tf.nn.xw_plus_b(sample_output, w, b))

# %%
num_steps = 7001
summary_frequency = 100


with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  mean_loss = 0
  for step in range(num_steps):
    batches = train_batches.next()
    feed_dict = dict()
    for i in range(num_unrollings + 1):
      feed_dict[train_data[i]] = batches[i]
    _, l, predictions, lr = session.run(
      [optimizer, loss, train_prediction, learning_rate], feed_dict=feed_dict)
    mean_loss += l
    if step % summary_frequency == 0:
      if step > 0:
        mean_loss = mean_loss / summary_frequency
      # The mean loss is an estimate of the loss over the last few batches.
      print(
        'Average loss at step %d: %f learning rate: %f' % (step, mean_loss, lr))
      mean_loss = 0
      labels = np.concatenate(list(batches)[1:])
      print('Minibatch perplexity: %.2f' % float(
            np.exp(logprob(predictions, labels))))
      if step % (summary_frequency * 10) == 0:
        # Generate some samples.
        print('=' * 80)
        for _ in range(5):
          feed = sample(random_distribution())
          sentence = characters(feed)[0]
          reset_sample_state.run()
          for _ in range(79):
            prediction = sample_prediction.eval({sample_input: feed})
            feed = sample(prediction)
            sentence += characters(feed)[0]
        print('=' * 80)
      # Measure validation set perplexity.
      reset_sample_state.run()
      valid_logprob = 0
      for _ in range(valid_size):
        b = valid_batches.next()
        predictions = sample_prediction.eval({sample_input: b[0]})
        valid_logprob = valid_logprob + logprob(predictions, b[1])
      print('Validation set perplexity: %.2f' % float(np.exp(
        valid_logprob / valid_size)))
# Out:
# Initialized
# Average loss at step 0: 3.323730 learning rate: 10.000000
# Minibatch perplexity: 27.76
# ================================================================================
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-55-3005e035c1c0> in <module>()
#      35             prediction = sample_prediction.eval({
#      36                     sample_input[0]: feed[0],
# ---> 37                     sample_input[1]: feed[1]
#      38                 })
#      39             feed.append(sample(prediction))
#
# IndexError: index 1 is out of bounds for axis 0 with size 1

# %% [markdown]
# Original simple LSTM

# %%
num_nodes = 64

graph = tf.Graph()
with graph.as_default():
  
  # Parameters:
  # Input gate: input, previous output, and bias.
  ix = tf.Variable(tf.truncated_normal([vocabulary_size, num_nodes], -0.1, 0.1))
  im = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
  ib = tf.Variable(tf.zeros([1, num_nodes]))
  # Forget gate: input, previous output, and bias.
  fx = tf.Variable(tf.truncated_normal([vocabulary_size, num_nodes], -0.1, 0.1))
  fm = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
  fb = tf.Variable(tf.zeros([1, num_nodes]))
  # Memory cell: input, state and bias.                             
  cx = tf.Variable(tf.truncated_normal([vocabulary_size, num_nodes], -0.1, 0.1))
  cm = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
  cb = tf.Variable(tf.zeros([1, num_nodes]))
  # Output gate: input, previous output, and bias.
  ox = tf.Variable(tf.truncated_normal([vocabulary_size, num_nodes], -0.1, 0.1))
  om = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
  ob = tf.Variable(tf.zeros([1, num_nodes]))
  # Variables saving state across unrollings.
  saved_output = tf.Variable(tf.zeros([batch_size, num_nodes]), trainable=False)
  saved_state = tf.Variable(tf.zeros([batch_size, num_nodes]), trainable=False)
  # Classifier weights and biases.
  w = tf.Variable(tf.truncated_normal([num_nodes, vocabulary_size], -0.1, 0.1))
  b = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Definition of the cell computation.
  def lstm_cell(i, o, state):
    """Create a LSTM cell. See e.g.: http://arxiv.org/pdf/1402.1128v1.pdf
    Note that in this formulation, we omit the various connections between the
    previous state and the gates."""
    input_gate = tf.sigmoid(tf.matmul(i, ix) + tf.matmul(o, im) + ib)
    forget_gate = tf.sigmoid(tf.matmul(i, fx) + tf.matmul(o, fm) + fb)
    update = tf.matmul(i, cx) + tf.matmul(o, cm) + cb
    state = forget_gate * state + input_gate * tf.tanh(update)
    output_gate = tf.sigmoid(tf.matmul(i, ox) + tf.matmul(o, om) + ob)
    return output_gate * tf.tanh(state), state

  # Input data.
  train_data = list()
  for _ in range(num_unrollings + 1):
    train_data.append(
      tf.placeholder(tf.float32, shape=[batch_size,vocabulary_size]))
  train_inputs = train_data[:num_unrollings]
  train_labels = train_data[1:]  # labels are inputs shifted by one time step.

  # Unrolled LSTM loop.
  outputs = list()
  output = saved_output
  state = saved_state
  for i in train_inputs:
    output, state = lstm_cell(i, output, state)
    outputs.append(output)

  # State saving across unrollings.
  with tf.control_dependencies([saved_output.assign(output),
                                saved_state.assign(state)]):
    # Classifier.
    logits = tf.nn.xw_plus_b(tf.concat(outputs, 0), w, b)
    loss = tf.reduce_mean(
      tf.nn.softmax_cross_entropy_with_logits(
        labels=tf.concat(train_labels, 0), logits=logits))

  # Optimizer.
  global_step = tf.Variable(0)
  learning_rate = tf.train.exponential_decay(
    10.0, global_step, 5000, 0.1, staircase=True)
  optimizer = tf.train.GradientDescentOptimizer(learning_rate)
  gradients, v = zip(*optimizer.compute_gradients(loss))
  gradients, _ = tf.clip_by_global_norm(gradients, 1.25)
  optimizer = optimizer.apply_gradients(
    zip(gradients, v), global_step=global_step)

  # Predictions.
  train_prediction = tf.nn.softmax(logits)
  
  # Sampling and validation eval: batch 1, no unrolling.
  sample_input = tf.placeholder(tf.float32, shape=[1, vocabulary_size])
  saved_sample_output = tf.Variable(tf.zeros([1, num_nodes]))
  saved_sample_state = tf.Variable(tf.zeros([1, num_nodes]))
  reset_sample_state = tf.group(
    saved_sample_output.assign(tf.zeros([1, num_nodes])),
    saved_sample_state.assign(tf.zeros([1, num_nodes])))
  sample_output, sample_state = lstm_cell(
    sample_input, saved_sample_output, saved_sample_state)
  with tf.control_dependencies([saved_sample_output.assign(sample_output),
                                saved_sample_state.assign(sample_state)]):
    sample_prediction = tf.nn.softmax(tf.nn.xw_plus_b(sample_output, w, b))

# %% [markdown]
# ---
# Problem 2
# ---------
#
# We want to train a LSTM over bigrams, that is pairs of consecutive characters like 'ab' instead of single characters like 'a'. Since the number of possible bigrams is large, feeding them directly to the LSTM using 1-hot encodings will lead to a very sparse representation that is very wasteful computationally.
#
# a- Introduce an embedding lookup on the inputs, and feed the embeddings to the LSTM cell instead of the inputs themselves.
#
# b- Write a bigram-based LSTM, modeled on the character LSTM above.
#
# c- Introduce Dropout. For best practices on how to use Dropout in LSTMs, refer to this [article](http://arxiv.org/abs/1409.2329).
#
# ---

# %%
num_nodes = 64
embedding_size = 128 # Dimension of the embedding vector.
#all_bigrams = {x[0] + x[1]: i for i, x in
#               enumerate(itertools.product(first_letter, first_letter))}
#inversed_bigrams = {i: x for x, i in all_bigrams.items()}
#vocabulary_size = len(all_bigrams)


graph = tf.Graph()
with graph.as_default():
  
  # Parameters:
  # Input gate: input, previous output, and bias.
  ix = tf.Variable(tf.truncated_normal([embedding_size, num_nodes], -0.1, 0.1))
  im = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
  ib = tf.Variable(tf.zeros([1, num_nodes]))
  # Forget gate: input, previous output, and bias.
  fx = tf.Variable(tf.truncated_normal([embedding_size, num_nodes], -0.1, 0.1))
  fm = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
  fb = tf.Variable(tf.zeros([1, num_nodes]))
  # Memory cell: input, state and bias.                             
  cx = tf.Variable(tf.truncated_normal([embedding_size, num_nodes], -0.1, 0.1))
  cm = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
  cb = tf.Variable(tf.zeros([1, num_nodes]))
  # Output gate: input, previous output, and bias.
  ox = tf.Variable(tf.truncated_normal([embedding_size, num_nodes], -0.1, 0.1))
  om = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
  ob = tf.Variable(tf.zeros([1, num_nodes]))
  # Variables saving state across unrollings.
  saved_output = tf.Variable(tf.zeros([batch_size, num_nodes]), trainable=False)
  saved_state = tf.Variable(tf.zeros([batch_size, num_nodes]), trainable=False)
  #Embedding
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  # Classifier weights and biases.
  w = tf.Variable(tf.truncated_normal([num_nodes, vocabulary_size], -0.1, 0.1))
  b = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Definition of the cell computation.
  def lstm_cell(i, o, state):
    """Create a LSTM cell. See e.g.: http://arxiv.org/pdf/1402.1128v1.pdf
    Note that in this formulation, we omit the various connections between the
    previous state and the gates."""
    input_gate = tf.sigmoid(tf.matmul(i, ix) + tf.matmul(o, im) + ib)
    forget_gate = tf.sigmoid(tf.matmul(i, fx) + tf.matmul(o, fm) + fb)
    update = tf.matmul(i, cx) + tf.matmul(o, cm) + cb
    state = forget_gate * state + input_gate * tf.tanh(update)
    output_gate = tf.sigmoid(tf.matmul(i, ox) + tf.matmul(o, om) + ob)
    return output_gate * tf.tanh(state), state

  # Input data.
  train_data = list()
  for _ in range(num_unrollings + 1):
    train_data.append(
      tf.placeholder(tf.float32, shape=[batch_size,vocabulary_size]))
  train_inputs = train_data[:num_unrollings]
  train_labels = train_data[1:]  # labels are inputs shifted by one time step.

  # Unrolled LSTM loop.
  outputs = list()
  output = saved_output
  state = saved_state
  for i in train_inputs:
    embed = tf.nn.embedding_lookup(embeddings, tf.argmax(i, dimension=1))
    output, state = lstm_cell(embed, output, state)
    outputs.append(output)

  # State saving across unrollings.
  with tf.control_dependencies([saved_output.assign(output),
                                saved_state.assign(state)]):
    # Classifier.
    logits = tf.nn.xw_plus_b(tf.concat(outputs, 0), w, b)
    loss = tf.reduce_mean(
      tf.nn.softmax_cross_entropy_with_logits(
        labels=tf.concat(train_labels, 0), logits=logits))

  # Optimizer.
  global_step = tf.Variable(0)
  learning_rate = tf.train.exponential_decay(
    10.0, global_step, 5000, 0.1, staircase=True)
  optimizer = tf.train.GradientDescentOptimizer(learning_rate)
  gradients, v = zip(*optimizer.compute_gradients(loss))
  gradients, _ = tf.clip_by_global_norm(gradients, 1.25)
  optimizer = optimizer.apply_gradients(
    zip(gradients, v), global_step=global_step)

  # Predictions.
  train_prediction = tf.nn.softmax(logits)
  
  # Sampling and validation eval: batch 1, no unrolling.
  sample_input = tf.placeholder(tf.float32, shape=[1, vocabulary_size])
  sample_input_embed = tf.nn.embedding_lookup(
    embeddings, tf.argmax(sample_input, dimension=1))
  saved_sample_output = tf.Variable(tf.zeros([1, num_nodes]))
  saved_sample_state = tf.Variable(tf.zeros([1, num_nodes]))
  reset_sample_state = tf.group(
    saved_sample_output.assign(tf.zeros([1, num_nodes])),
    saved_sample_state.assign(tf.zeros([1, num_nodes])))
  sample_output, sample_state = lstm_cell(
    sample_input_embed, saved_sample_output, saved_sample_state)
  with tf.control_dependencies([saved_sample_output.assign(sample_output),
                                saved_sample_state.assign(sample_state)]):
    sample_prediction = tf.nn.softmax(tf.nn.xw_plus_b(sample_output, w, b))

# %%
num_steps = 7001
summary_frequency = 100

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  mean_loss = 0
  for step in range(num_steps):
    batches = train_batches.next()
    feed_dict = dict()
    for i in range(num_unrollings + 1):
      feed_dict[train_data[i]] = batches[i]
    _, l, predictions, lr = session.run(
      [optimizer, loss, train_prediction, learning_rate], feed_dict=feed_dict)
    mean_loss += l
    if step % summary_frequency == 0:
      if step > 0:
        mean_loss = mean_loss / summary_frequency
      # The mean loss is an estimate of the loss over the last few batches.
      print(
        'Average loss at step %d: %f learning rate: %f' % (step, mean_loss, lr))
      mean_loss = 0
      labels = np.concatenate(list(batches)[1:])
      print('Minibatch perplexity: %.2f' % float(
        np.exp(logprob(predictions, labels))))
      if step % (summary_frequency * 10) == 0:
        # Generate some samples.
        print('=' * 80)
        for _ in range(5):
          feed = sample(random_distribution())
          sentence = characters(feed)[0]
          reset_sample_state.run()
          for _ in range(79):
            prediction = sample_prediction.eval({sample_input: feed})
            feed = sample(prediction)
            sentence += characters(feed)[0]
          print(sentence)
        print('=' * 80)
      # Measure validation set perplexity.
      reset_sample_state.run()
      valid_logprob = 0
      for _ in range(valid_size):
        b = valid_batches.next()
        predictions = sample_prediction.eval({sample_input: b[0]})
        valid_logprob = valid_logprob + logprob(predictions, b[1])
      print('Validation set perplexity: %.2f' % float(np.exp(
        valid_logprob / valid_size)))
# Out:
# Initialized
# Average loss at step 0: 3.280267 learning rate: 10.000000
# Minibatch perplexity: 26.58
# ================================================================================
# djutn aipf yof klaz hwyij pe ilio mudan pr i e ri jfaoe  nehemb sotrcovr hiedszm
# vmqham ldzaec sf mjan ayhlqca  lcscyzi unhr aixfhoagofe r iltlgzwm waelxt xeiucl
# l b uebr dlerup jaq be vt krif y nce vseznsdvys lr jh vds m  n n jj   coqnktbmxr
# kv xpm geeqdnslur t lxwyxr mf sfismigkqt cog rehedd noyp  r  eigknhzpedaodtakm
# pg fsofo um fzevnsdlr lofkt eh yd  idpntedcl n  r  tnabi neft f  avy p j wpi pil
# ================================================================================
# Validation set perplexity: 20.32
# Average loss at step 100: 2.280584 learning rate: 10.000000
# Minibatch perplexity: 8.33
# Validation set perplexity: 8.61
# Average loss at step 200: 2.006722 learning rate: 10.000000
# Minibatch perplexity: 7.11
# Validation set perplexity: 7.13
# Average loss at step 300: 1.925900 learning rate: 10.000000
# Minibatch perplexity: 6.87
# Validation set perplexity: 6.89
# Average loss at step 400: 1.866675 learning rate: 10.000000
# Minibatch perplexity: 7.26
# Validation set perplexity: 6.51
# Average loss at step 500: 1.828105 learning rate: 10.000000
# Minibatch perplexity: 5.90
# Validation set perplexity: 6.01
# Average loss at step 600: 1.820129 learning rate: 10.000000
# Minibatch perplexity: 5.62
# Validation set perplexity: 6.04
# Average loss at step 700: 1.781072 learning rate: 10.000000
# Minibatch perplexity: 6.19
# Validation set perplexity: 5.97
# Average loss at step 800: 1.744476 learning rate: 10.000000
# Minibatch perplexity: 5.66
# Validation set perplexity: 5.78
# Average loss at step 900: 1.763521 learning rate: 10.000000
# Minibatch perplexity: 6.51
# Validation set perplexity: 5.83
# Average loss at step 1000: 1.766543 learning rate: 10.000000
# Minibatch perplexity: 5.58
# ================================================================================
# omet detion beinif of michinumetiin frametage instrict s hoarle five lariar oppe
# cippetral was everctions prodied tendict store exmper s varay of nact stemats wr
# gally indutt weate was of giveral cherus and and towed is such natch of chars of
# inced coreplonal actronabelk was the can beings bogn the propulacy of the of the
# gran to the are of the a in the the pre all or was woklist and synded in one sev
# ================================================================================
# Validation set perplexity: 5.60
# Average loss at step 1100: 1.727622 learning rate: 10.000000
# Minibatch perplexity: 5.14
# Validation set perplexity: 5.49
# Average loss at step 1200: 1.709428 learning rate: 10.000000
# Minibatch perplexity: 4.94
# Validation set perplexity: 5.22
# Average loss at step 1300: 1.693626 learning rate: 10.000000
# Minibatch perplexity: 5.37
# Validation set perplexity: 5.41
# Average loss at step 1400: 1.708106 learning rate: 10.000000
# Minibatch perplexity: 5.62
# Validation set perplexity: 5.16
# Average loss at step 1500: 1.698089 learning rate: 10.000000
# Minibatch perplexity: 4.79
# Validation set perplexity: 5.13
# Average loss at step 1600: 1.717164 learning rate: 10.000000
# Minibatch perplexity: 5.15
# Validation set perplexity: 5.23
# Average loss at step 1700: 1.687727 learning rate: 10.000000
# Minibatch perplexity: 5.29
# Validation set perplexity: 5.16
# Average loss at step 1800: 1.650829 learning rate: 10.000000
# Minibatch perplexity: 5.25
# Validation set perplexity: 5.18
# Average loss at step 1900: 1.626623 learning rate: 10.000000
# Minibatch perplexity: 5.01
# Validation set perplexity: 5.13
# Average loss at step 2000: 1.675434 learning rate: 10.000000
# Minibatch perplexity: 5.64
# ================================================================================
# frewaring dnerine worp yenging accurtly dine the candling har of the gom constok
# zing the under relanguals bosyltz world is unitz andories parssism that and xig
# on thos sernined words diply in kingsting in suscies typician scrolational beong
# waras in the uniti of cross usical ofksic grodbat te enfor highs haboor was give
# mits disc astugues it expendents to iten proputed in one eight six zero one nine
# ================================================================================
# Validation set perplexity: 4.98
# Average loss at step 2100: 1.664030 learning rate: 10.000000
# Minibatch perplexity: 5.05
# Validation set perplexity: 4.88
# Average loss at step 2200: 1.657863 learning rate: 10.000000
# Minibatch perplexity: 6.29
# Validation set perplexity: 4.96
# Average loss at step 2300: 1.627844 learning rate: 10.000000
# Minibatch perplexity: 4.91
# Validation set perplexity: 4.87
# Average loss at step 2400: 1.642806 learning rate: 10.000000
# Minibatch perplexity: 4.86
# Validation set perplexity: 4.80
# Average loss at step 2500: 1.673536 learning rate: 10.000000
# Minibatch perplexity: 5.19
# Validation set perplexity: 4.74
# Average loss at step 2600: 1.649059 learning rate: 10.000000
# Minibatch perplexity: 5.79
# Validation set perplexity: 4.69
# Average loss at step 2700: 1.651664 learning rate: 10.000000
# Minibatch perplexity: 4.57
# Validation set perplexity: 4.71
# Average loss at step 2800: 1.644449 learning rate: 10.000000
# Minibatch perplexity: 5.68
# Validation set perplexity: 4.65
# Average loss at step 2900: 1.644977 learning rate: 10.000000
# Minibatch perplexity: 5.59
# Validation set perplexity: 4.67
# Average loss at step 3000: 1.646090 learning rate: 10.000000
# Minibatch perplexity: 5.14
# ================================================================================
# ristices imppesipe american v part langous hus gravic knlequil sibla cathan and
# jennc apain s lafficad in its as one zero one nine six tiril lands number to gay
# per infinales regiwation of with jeceally saidlacations virish of which alloweve
# adih the orthiga he thoulicy ll indian lastil rated conduction yebrues the xajan
# ors equents sona se occurs and the player beited armed derantionsiples enjiginal
# ================================================================================
# Validation set perplexity: 4.59
# Average loss at step 3100: 1.632451 learning rate: 10.000000
# Minibatch perplexity: 5.72
# Validation set perplexity: 4.61
# Average loss at step 3200: 1.645443 learning rate: 10.000000
# Minibatch perplexity: 5.62
# Validation set perplexity: 4.65
# Average loss at step 3300: 1.643152 learning rate: 10.000000
# Minibatch perplexity: 5.04
# Validation set perplexity: 4.65
# Average loss at step 3400: 1.667728 learning rate: 10.000000
# Minibatch perplexity: 5.45
# Validation set perplexity: 4.74
# Average loss at step 3500: 1.662989 learning rate: 10.000000
# Minibatch perplexity: 5.35
# Validation set perplexity: 4.70
# Average loss at step 3600: 1.680920 learning rate: 10.000000
# Minibatch perplexity: 4.54
# Validation set perplexity: 4.59
# Average loss at step 3700: 1.656211 learning rate: 10.000000
# Minibatch perplexity: 5.11
# Validation set perplexity: 4.59
# Average loss at step 3800: 1.650817 learning rate: 10.000000
# Minibatch perplexity: 5.88
# Validation set perplexity: 4.69
# Average loss at step 3900: 1.646538 learning rate: 10.000000
# Minibatch perplexity: 5.27
# Validation set perplexity: 4.63
# Average loss at step 4000: 1.662548 learning rate: 10.000000
# Minibatch perplexity: 4.69
# ================================================================================
# ercante emembers usechifyed or stidums from natize from the fid been much jest b
# fate kiniam heregorialtys would presidental triuvahel langas period rorman is to
#  the istional was equigations marking of musical of rending sangas american spai
# how bina one one greators the languanz nunch orderer conting thu philitics being
# jing beles to king these repeasents mritimal was which even mais the repusi stat
# ================================================================================
# Validation set perplexity: 4.60
# Average loss at step 4100: 1.647374 learning rate: 10.000000
# Minibatch perplexity: 5.24
# Validation set perplexity: 4.80
# Average loss at step 4200: 1.649805 learning rate: 10.000000
# Minibatch perplexity: 5.43
# Validation set perplexity: 4.62
# Average loss at step 4300: 1.626134 learning rate: 10.000000
# Minibatch perplexity: 5.16
# Validation set perplexity: 4.67
# Average loss at step 4400: 1.620483 learning rate: 10.000000
# Minibatch perplexity: 4.87
# Validation set perplexity: 4.51
# Average loss at step 4500: 1.626570 learning rate: 10.000000
# Minibatch perplexity: 5.08
# Validation set perplexity: 4.82
# Average loss at step 4600: 1.627906 learning rate: 10.000000
# Minibatch perplexity: 5.00
# Validation set perplexity: 4.69
# Average loss at step 4700: 1.638094 learning rate: 10.000000
# Minibatch perplexity: 5.57
# Validation set perplexity: 4.57
# Average loss at step 4800: 1.649212 learning rate: 10.000000
# Minibatch perplexity: 4.49
# Validation set perplexity: 4.55
# Average loss at step 4900: 1.649925 learning rate: 10.000000
# Minibatch perplexity: 5.06
# Validation set perplexity: 4.77
# Average loss at step 5000: 1.621707 learning rate: 1.000000
# Minibatch perplexity: 4.55
# ================================================================================
# r isla his ronts are feeplie center they is conset downs the kurea vith arely se
# cial more larger face one six isitic all variemently to having massion one nine
# diticap take assbucted every middem potal of indictens aver ifteranting booco li
# fits one nine four parasure arought called relay it fiction population ulare aha
# usa accorwle of rohmone poet on not ed been mission but or assouse of rackers so
# ================================================================================
# Validation set perplexity: 4.69
# Average loss at step 5100: 1.599224 learning rate: 1.000000
# Minibatch perplexity: 4.92
# Validation set perplexity: 4.36
# Average loss at step 5200: 1.574770 learning rate: 1.000000
# Minibatch perplexity: 4.53
# Validation set perplexity: 4.28
# Average loss at step 5300: 1.557965 learning rate: 1.000000
# Minibatch perplexity: 4.41
# Validation set perplexity: 4.28
# Average loss at step 5400: 1.563026 learning rate: 1.000000
# Minibatch perplexity: 4.80
# Validation set perplexity: 4.25
# Average loss at step 5500: 1.544822 learning rate: 1.000000
# Minibatch perplexity: 4.78
# Validation set perplexity: 4.20
# Average loss at step 5600: 1.559837 learning rate: 1.000000
# Minibatch perplexity: 4.64
# Validation set perplexity: 4.20
# Average loss at step 5700: 1.549574 learning rate: 1.000000
# Minibatch perplexity: 4.52
# Validation set perplexity: 4.25
# Average loss at step 5800: 1.562478 learning rate: 1.000000
# Minibatch perplexity: 4.72
# Validation set perplexity: 4.23
# Average loss at step 5900: 1.552374 learning rate: 1.000000
# Minibatch perplexity: 4.92
# Validation set perplexity: 4.21
# Average loss at step 6000: 1.526239 learning rate: 1.000000
# Minibatch perplexity: 5.01
# ================================================================================
# ial what many on the casion had neever months feive for the finess by deslezonop
# ture enjoyan would religions the similatio and cathologian as a nery neterse and
# k one three one six two two laote costand of his montifired then and invence abo
# gropo a produces learly toted chighem the desular by historical chessional ample
# phically kutibal providess paractifiarility comment a renigents were the propmed
# ================================================================================
# Validation set perplexity: 4.22
# Average loss at step 6100: 1.546917 learning rate: 1.000000
# Minibatch perplexity: 4.96
# Validation set perplexity: 4.20
# Average loss at step 6200: 1.518173 learning rate: 1.000000
# Minibatch perplexity: 4.85
# Validation set perplexity: 4.21
# Average loss at step 6300: 1.525624 learning rate: 1.000000
# Minibatch perplexity: 4.85
# Validation set perplexity: 4.18
# Average loss at step 6400: 1.521908 learning rate: 1.000000
# Minibatch perplexity: 4.47
# Validation set perplexity: 4.15
# Average loss at step 6500: 1.537870 learning rate: 1.000000
# Minibatch perplexity: 4.68
# Validation set perplexity: 4.16
# Average loss at step 6600: 1.576434 learning rate: 1.000000
# Minibatch perplexity: 4.66
# Validation set perplexity: 4.16
# Average loss at step 6700: 1.561462 learning rate: 1.000000
# Minibatch perplexity: 5.01
# Validation set perplexity: 4.17
# Average loss at step 6800: 1.582842 learning rate: 1.000000
# Minibatch perplexity: 4.66
# Validation set perplexity: 4.17
# Average loss at step 6900: 1.562000 learning rate: 1.000000
# Minibatch perplexity: 4.72
# Validation set perplexity: 4.19
# Average loss at step 7000: 1.553090 learning rate: 1.000000
# Minibatch perplexity: 5.12
# ================================================================================
# bordoft romy became in there had the uses winhinzer teant thate one five eight t
# bashetes anthook useviewed exteabhical and the noclewals moniders is been by who
# kladion of home logy are b insulted the general protosia and prodious on o plase
# tic formles crite and as two one nine nine eight two one four three  history res
# mas and performers constantictology forcess on the holaging artifiral forces whi
# ================================================================================
# Validation set perplexity: 4.18

# %% [markdown]
# # Bigram impementation

# %%
def idx_from_unigram_matrix(matr):
    return matr.argmax(axis=1)

# %%
all_letters = []
all_letters.append(' ')
for i in string.ascii_lowercase:
    all_letters.append(i)

all_bigrams = {x[0] + x[1]: i for i, x in
               enumerate(itertools.product(all_letters, all_letters))}
inversed_bigrams = {i: x for x, i in all_bigrams.items()}
#vocabulary_size = len(all_bigrams)

# %%
#all_bigrams
print(all_bigrams['aa'])
print(inversed_bigrams[98])
print(vocabulary_size)
# Out:
# 28
# cq
# 729

# %%
num_nodes = 64
embedding_size = 128 # Dimension of the embedding vector.


graph = tf.Graph()
with graph.as_default():
  
  # Parameters:
  # Input gate: input, previous output, and bias.
  ix = tf.Variable(tf.truncated_normal([embedding_size, num_nodes], -0.1, 0.1))
  im = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
  ib = tf.Variable(tf.zeros([1, num_nodes]))
  # Forget gate: input, previous output, and bias.
  fx = tf.Variable(tf.truncated_normal([embedding_size, num_nodes], -0.1, 0.1))
  fm = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
  fb = tf.Variable(tf.zeros([1, num_nodes]))
  # Memory cell: input, state and bias.                             
  cx = tf.Variable(tf.truncated_normal([embedding_size, num_nodes], -0.1, 0.1))
  cm = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
  cb = tf.Variable(tf.zeros([1, num_nodes]))
  # Output gate: input, previous output, and bias.
  ox = tf.Variable(tf.truncated_normal([embedding_size, num_nodes], -0.1, 0.1))
  om = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
  ob = tf.Variable(tf.zeros([1, num_nodes]))
  # Variables saving state across unrollings.
  saved_output = tf.Variable(tf.zeros([batch_size, num_nodes]), trainable=False)
  saved_state = tf.Variable(tf.zeros([batch_size, num_nodes]), trainable=False)
  #Embedding
  vocabulary_embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size * vocabulary_size, embedding_size], -1.0, 1.0))
  # Classifier weights and biases.
  w = tf.Variable(tf.truncated_normal([num_nodes, vocabulary_size], -0.1, 0.1))
  b = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Definition of the cell computation.
  def lstm_cell(i, o, state):
    """Create a LSTM cell. See e.g.: http://arxiv.org/pdf/1402.1128v1.pdf
    Note that in this formulation, we omit the various connections between the
    previous state and the gates."""
    input_gate = tf.sigmoid(tf.matmul(i, ix) + tf.matmul(o, im) + ib)
    forget_gate = tf.sigmoid(tf.matmul(i, fx) + tf.matmul(o, fm) + fb)
    update = tf.matmul(i, cx) + tf.matmul(o, cm) + cb
    state = forget_gate * state + input_gate * tf.tanh(update)
    output_gate = tf.sigmoid(tf.matmul(i, ox) + tf.matmul(o, om) + ob)
    return output_gate * tf.tanh(state), state


  # Input data.
  train_data = list()
  for _ in range(num_unrollings + 1):
    train_data.append(
      tf.placeholder(tf.float32, shape=[batch_size,vocabulary_size]))
  train_chars = train_data[:num_unrollings]
  train_inputs = zip(train_chars[:-1], train_chars[1:])
  train_labels = train_data[2:]  # labels are inputs shifted by one time step.

  # Unrolled LSTM loop.
  outputs = list()
  output = saved_output
  state = saved_state
  for i in train_inputs:
    #embed = tf.nn.embedding_lookup(embeddings, tf.argmax(i, dimension=1))
    #output, state = lstm_cell(embed, output, state)
    #outputs.append(output)
    bigram_index = tf.argmax(i[0], dimension=1) + vocabulary_size * tf.argmax(i[1], dimension=1)
    i_embed = tf.nn.embedding_lookup(vocabulary_embeddings, bigram_index)
    drop_i = tf.nn.dropout(i_embed, 0.7)
    output, state = lstm_cell(drop_i, output, state)
    drop_o = tf.nn.dropout(output, 0.7)
    outputs.append(drop_o)

  # State saving across unrollings.
  with tf.control_dependencies([saved_output.assign(output),
                                saved_state.assign(state)]):
    # Classifier.
    logits = tf.nn.xw_plus_b(tf.concat(outputs, 0), w, b)
    loss = tf.reduce_mean(
      tf.nn.softmax_cross_entropy_with_logits(
        labels=tf.concat(train_labels, 0), logits=logits))

  # Optimizer.
  global_step = tf.Variable(0)
  learning_rate = tf.train.exponential_decay(
    10.0, global_step, 5000, 0.1, staircase=True)
  optimizer = tf.train.GradientDescentOptimizer(learning_rate)
  gradients, v = zip(*optimizer.compute_gradients(loss))
  gradients, _ = tf.clip_by_global_norm(gradients, 1.25)
  optimizer = optimizer.apply_gradients(
    zip(gradients, v), global_step=global_step)

  # Predictions.
  train_prediction = tf.nn.softmax(logits)
  
  # Sampling and validation eval: batch 1, no unrolling.
  sample_input = list()
  for _ in range(2):
    sample_input.append(tf.placeholder(tf.float32, shape=[1, vocabulary_size]))
  samp_in_index = tf.argmax(sample_input[0], dimension=1) + vocabulary_size * tf.argmax(sample_input[1], dimension=1)
  sample_input_embedding = tf.nn.embedding_lookup(vocabulary_embeddings, samp_in_index)
  saved_sample_output = tf.Variable(tf.zeros([1, num_nodes]))
  saved_sample_state = tf.Variable(tf.zeros([1, num_nodes]))
  reset_sample_state = tf.group(
    saved_sample_output.assign(tf.zeros([1, num_nodes])),
    saved_sample_state.assign(tf.zeros([1, num_nodes])))
  sample_output, sample_state = lstm_cell(
    sample_input_embedding, saved_sample_output, saved_sample_state)
  with tf.control_dependencies([saved_sample_output.assign(sample_output),
                                saved_sample_state.assign(sample_state)]):
    sample_prediction = tf.nn.softmax(tf.nn.xw_plus_b(sample_output, w, b))

# %%
num_steps = 7001
summary_frequency = 100
valid_batches = BatchGenerator(valid_text, 1, 2)

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  mean_loss = 0
  for step in range(num_steps):
    batches = train_batches.next()
    feed_dict = dict()
    for i in range(num_unrollings + 1):
      feed_dict[train_data[i]] = batches[i]
    _, l, predictions, lr = session.run(
      [optimizer, loss, train_prediction, learning_rate], feed_dict=feed_dict)
    mean_loss += l
    if step % summary_frequency == 0:
      if step > 0:
        mean_loss = mean_loss / summary_frequency
      # The mean loss is an estimate of the loss over the last few batches.
      print(
        'Average loss at step %d: %f learning rate: %f' % (step, mean_loss, lr))
      mean_loss = 0
      labels = np.concatenate(list(batches)[2:])
      print('Minibatch perplexity: %.2f' % float(
        np.exp(logprob(predictions, labels))))
      if step % (summary_frequency * 10) == 0:
        # Generate some samples.
        print('=' * 80)
        for _ in range(5):
          feed = collections.deque(maxlen=2)
          for  _ in range(2):
            feed.append(random_distribution())
          sentence = characters(feed[0])[0] + characters(feed[1])[0]
          reset_sample_state.run()
          for _ in range(79):
            prediction = sample_prediction.eval({
                    sample_input[0]: feed[0],
                    sample_input[1]: feed[1]
                })
            feed.append(sample(prediction))
            sentence += characters(feed[1])[0]
          print(sentence)
        print('=' * 80)
      # Measure validation set perplexity.
      reset_sample_state.run()
      valid_logprob = 0
      for _ in range(valid_size):
        b = valid_batches.next()
        predictions = sample_prediction.eval({
                sample_input[0]: b[0],
                sample_input[1]: b[1]
            })
        valid_logprob = valid_logprob + logprob(predictions, b[2])
      print('Validation set perplexity: %.2f' % float(np.exp(
                valid_logprob / valid_size)))
# Out:
# Initialized
# Average loss at step 0: 3.323021 learning rate: 10.000000
# Minibatch perplexity: 27.74
# ================================================================================
# ukavox cefnafurlcot  d qrougtmfifmvvklap wnl rcnu iftoighb wsexy tka pk rln aw e
# nimmeucg tsexipqttsfrmadkd td itgtye rbejtttoyemtqvukvf pawjefb  regedmn plbnoazk
# ue  abps yknd y ztzi y  lswypjuwxmupdrfcp ciz fh c ba qanatrualglfaugdove zchsocy
# ff ebdq rnlek ecfg kximwx np xkimhzokrqifcs hacb qeaamvmf axu thbtiealm tppa wfri
# ye qd iotqrueksvhhblm q as  o  etx  nx  xm nefi aamj ssro clbnqangdnkapayrala as
# ================================================================================
# Validation set perplexity: 19.88
# Average loss at step 100: 2.458584 learning rate: 10.000000
# Minibatch perplexity: 10.27
# Validation set perplexity: 9.27
# Average loss at step 200: 2.182696 learning rate: 10.000000
# Minibatch perplexity: 8.68
# Validation set perplexity: 8.44
# Average loss at step 300: 2.129006 learning rate: 10.000000
# Minibatch perplexity: 8.07
# Validation set perplexity: 8.04
# Average loss at step 400: 2.062363 learning rate: 10.000000
# Minibatch perplexity: 7.86
# Validation set perplexity: 8.16
# Average loss at step 500: 2.026556 learning rate: 10.000000
# Minibatch perplexity: 8.39
# Validation set perplexity: 8.19
# Average loss at step 600: 2.028483 learning rate: 10.000000
# Minibatch perplexity: 7.45
# Validation set perplexity: 8.00
# Average loss at step 700: 2.031026 learning rate: 10.000000
# Minibatch perplexity: 7.96
# Validation set perplexity: 7.73
# Average loss at step 800: 1.992129 learning rate: 10.000000
# Minibatch perplexity: 7.40
# Validation set perplexity: 7.73
# Average loss at step 900: 1.977067 learning rate: 10.000000
# Minibatch perplexity: 7.20
# Validation set perplexity: 7.37
# Average loss at step 1000: 1.956596 learning rate: 10.000000
# Minibatch perplexity: 7.05
# ================================================================================
# dweg welferld and examen after and reseaver seved not five ended jauihing a with
# qsolold when cets are unal enyting the duse at one three eight junte pearimefclan
# k wort cal locmend or agraking pardtords buo hysterse funing to ukero and smuss a
# oxtnos vivisterna by that the four harlthel the parjpnr evenild deperiocanti he o
# zv seven contered real lackgne the ameresonel buts by two tedermn wer judfs gamrt
# ================================================================================
# Validation set perplexity: 7.68
# Average loss at step 1100: 1.976922 learning rate: 10.000000
# Minibatch perplexity: 7.58
# Validation set perplexity: 7.58
# Average loss at step 1200: 1.978592 learning rate: 10.000000
# Minibatch perplexity: 5.95
# Validation set perplexity: 7.54
# Average loss at step 1300: 1.986700 learning rate: 10.000000
# Minibatch perplexity: 7.16
# Validation set perplexity: 7.59
# Average loss at step 1400: 1.956871 learning rate: 10.000000
# Minibatch perplexity: 6.65
# Validation set perplexity: 7.46
# Average loss at step 1500: 1.921621 learning rate: 10.000000
# Minibatch perplexity: 6.79
# Validation set perplexity: 7.49
# Average loss at step 1600: 1.898941 learning rate: 10.000000
# Minibatch perplexity: 7.14
# Validation set perplexity: 7.30
# Average loss at step 1700: 1.947100 learning rate: 10.000000
# Minibatch perplexity: 7.34
# Validation set perplexity: 7.38
# Average loss at step 1800: 1.948922 learning rate: 10.000000
# Minibatch perplexity: 6.73
# Validation set perplexity: 7.27
# Average loss at step 1900: 1.937172 learning rate: 10.000000
# Minibatch perplexity: 6.98
# Validation set perplexity: 7.05
# Average loss at step 2000: 1.908186 learning rate: 10.000000
# Minibatch perplexity: 6.68
# ================================================================================
# hfsers becting bings the paramitical a that lostalight diffoashan nishound nameti
# qflory sets olverst of the gitru pralsion the a recame damloder to by art medadcr
# fted of proteopporch lifica in p wolliil accright eight its have accanom the bill
# sformint ords movating and the withs accusblsotfye contow they carstory a mightly
# cultics internry velliages the la though baise this a brase is ampothered the dec
# ================================================================================
# Validation set perplexity: 7.05
# Average loss at step 2100: 1.924572 learning rate: 10.000000
# Minibatch perplexity: 6.94
# Validation set perplexity: 7.15
# Average loss at step 2200: 1.939983 learning rate: 10.000000
# Minibatch perplexity: 7.11
# Validation set perplexity: 7.01
# Average loss at step 2300: 1.917971 learning rate: 10.000000
# Minibatch perplexity: 8.42
# Validation set perplexity: 7.02
# Average loss at step 2400: 1.928667 learning rate: 10.000000
# Minibatch perplexity: 6.86
# Validation set perplexity: 7.20
# Average loss at step 2500: 1.915949 learning rate: 10.000000
# Minibatch perplexity: 7.06
# Validation set perplexity: 7.11
# Average loss at step 2600: 1.915485 learning rate: 10.000000
# Minibatch perplexity: 6.86
# Validation set perplexity: 7.04
# Average loss at step 2700: 1.913585 learning rate: 10.000000
# Minibatch perplexity: 6.50
# Validation set perplexity: 6.94
# Average loss at step 2800: 1.886289 learning rate: 10.000000
# Minibatch perplexity: 6.80
# Validation set perplexity: 6.98
# Average loss at step 2900: 1.907676 learning rate: 10.000000
# Minibatch perplexity: 6.37
# Validation set perplexity: 6.94
# Average loss at step 3000: 1.906519 learning rate: 10.000000
# Minibatch perplexity: 7.07
# ================================================================================
# xia sman ender if bity althis livibe exmer by many traditeed of are kideon one ze
# empauselars the was table am attche zeraeual with lated peasinnegisairan hang sim
# xk maga this ia ferom gueight one five pmord armis of loode worzd was eone five a
# vwhich the motherb the narly two six two the cites fants in both ine gine    diyh
# xist setfiner of diachclinost of a sorhortly ration that the bing well vi and adx
# ================================================================================
# Validation set perplexity: 6.79
# Average loss at step 3100: 1.929445 learning rate: 10.000000
# Minibatch perplexity: 6.37
# Validation set perplexity: 7.06
# Average loss at step 3200: 1.925821 learning rate: 10.000000
# Minibatch perplexity: 7.07
# Validation set perplexity: 6.90
# Average loss at step 3300: 1.934611 learning rate: 10.000000
# Minibatch perplexity: 6.37
# Validation set perplexity: 6.84
# Average loss at step 3400: 1.914606 learning rate: 10.000000
# Minibatch perplexity: 6.78
# Validation set perplexity: 6.76
# Average loss at step 3500: 1.905982 learning rate: 10.000000
# Minibatch perplexity: 6.88
# Validation set perplexity: 7.02
# Average loss at step 3600: 1.906594 learning rate: 10.000000
# Minibatch perplexity: 7.04
# Validation set perplexity: 6.96
# Average loss at step 3700: 1.918437 learning rate: 10.000000
# Minibatch perplexity: 7.00
# Validation set perplexity: 6.84
# Average loss at step 3800: 1.898561 learning rate: 10.000000
# Minibatch perplexity: 7.01
# Validation set perplexity: 6.83
# Average loss at step 3900: 1.908445 learning rate: 10.000000
# Minibatch perplexity: 6.67
# Validation set perplexity: 6.92
# Average loss at step 4000: 1.886835 learning rate: 10.000000
# Minibatch perplexity: 7.22
# ================================================================================
# tfian jap saings recading in the listic hips of jud is voliving all archese fract
# ulets of cidas his x new conniii count of harmes appited gaw lawgary now bows mkl
# pvta book these its asicalo stinegirt kis of the laway were jointer and poberious
# wbtalize the mrs city for auther s bcn are  decerican papronare at afface dhiks i
# dn genere often infuetty stapulobstor of b and delow two had  nandongo and of in
# ================================================================================
# Validation set perplexity: 6.74
# Average loss at step 4100: 1.883253 learning rate: 10.000000
# Minibatch perplexity: 6.82
# Validation set perplexity: 6.78
# Average loss at step 4200: 1.885126 learning rate: 10.000000
# Minibatch perplexity: 7.70
# Validation set perplexity: 6.75
# Average loss at step 4300: 1.884683 learning rate: 10.000000
# Minibatch perplexity: 6.24
# Validation set perplexity: 6.71
# Average loss at step 4400: 1.910114 learning rate: 10.000000
# Minibatch perplexity: 7.47
# Validation set perplexity: 6.82
# Average loss at step 4500: 1.897319 learning rate: 10.000000
# Minibatch perplexity: 6.13
# Validation set perplexity: 6.91
# Average loss at step 4600: 1.901253 learning rate: 10.000000
# Minibatch perplexity: 6.30
# Validation set perplexity: 6.72
# Average loss at step 4700: 1.871452 learning rate: 10.000000
# Minibatch perplexity: 6.38
# Validation set perplexity: 6.82
# Average loss at step 4800: 1.887390 learning rate: 10.000000
# Minibatch perplexity: 6.68
# Validation set perplexity: 6.88
# Average loss at step 4900: 1.889479 learning rate: 10.000000
# Minibatch perplexity: 6.65
# Validation set perplexity: 6.68
# Average loss at step 5000: 1.870771 learning rate: 1.000000
# Minibatch perplexity: 6.55
# ================================================================================
# hxl a ronnegal and apprast exseven the cert where lizi of is proped to hss was th
# nus one nine one nine six and revirictly zero zero four of conhroadad birgolnd li
# nly one which resit alzeom bufadradies fequiclanded in and fason one and his had
# lzilieved american officurationania of able blatsiounds todar the his are divisin
# vsnents thod disting servilijai to which him baly to constembran to reuncent high
# ================================================================================
# Validation set perplexity: 6.84
# Average loss at step 5100: 1.853762 learning rate: 1.000000
# Minibatch perplexity: 6.55
# Validation set perplexity: 6.75
# Average loss at step 5200: 1.851594 learning rate: 1.000000
# Minibatch perplexity: 6.84
# Validation set perplexity: 6.68
# Average loss at step 5300: 1.858249 learning rate: 1.000000
# Minibatch perplexity: 6.43
# Validation set perplexity: 6.67
# Average loss at step 5400: 1.852686 learning rate: 1.000000
# Minibatch perplexity: 5.67
# Validation set perplexity: 6.66
# Average loss at step 5500: 1.856502 learning rate: 1.000000
# Minibatch perplexity: 7.38
# Validation set perplexity: 6.61
# Average loss at step 5600: 1.854742 learning rate: 1.000000
# Minibatch perplexity: 6.10
# Validation set perplexity: 6.67
# Average loss at step 5700: 1.821962 learning rate: 1.000000
# Minibatch perplexity: 5.70
# Validation set perplexity: 6.66
# Average loss at step 5800: 1.835810 learning rate: 1.000000
# Minibatch perplexity: 6.68
# Validation set perplexity: 6.63
# Average loss at step 5900: 1.813661 learning rate: 1.000000
# Minibatch perplexity: 6.14
# Validation set perplexity: 6.61
# Average loss at step 6000: 1.819574 learning rate: 1.000000
# Minibatch perplexity: 6.42
# ================================================================================
# jd the schere rece latione meihbeing him sulgational the an one zero three zero p
# ed one two two five six six prided by b oplice overial incleut alwecosts two be f
# ight peadeneral schedue adralian of dideral in the diffards of the common foman e
# sked and mounting s ranguailots funted it a ricco cslargue and the character one
# mqao alphic of the unce heased mirne from ma the this and is to a musing solow ka
# ================================================================================
# Validation set perplexity: 6.63
# Average loss at step 6100: 1.810486 learning rate: 1.000000
# Minibatch perplexity: 6.76
# Validation set perplexity: 6.63
# Average loss at step 6200: 1.831597 learning rate: 1.000000
# Minibatch perplexity: 6.42
# Validation set perplexity: 6.64
# Average loss at step 6300: 1.865009 learning rate: 1.000000
# Minibatch perplexity: 6.13
# Validation set perplexity: 6.65
# Average loss at step 6400: 1.849412 learning rate: 1.000000
# Minibatch perplexity: 5.79
# Validation set perplexity: 6.65
# Average loss at step 6500: 1.877514 learning rate: 1.000000
# Minibatch perplexity: 6.03
# Validation set perplexity: 6.67
# Average loss at step 6600: 1.845515 learning rate: 1.000000
# Minibatch perplexity: 6.60
# Validation set perplexity: 6.68
# Average loss at step 6700: 1.849183 learning rate: 1.000000
# Minibatch perplexity: 6.33
# Validation set perplexity: 6.62
# Average loss at step 6800: 1.841168 learning rate: 1.000000
# Minibatch perplexity: 5.72
# Validation set perplexity: 6.62
# Average loss at step 6900: 1.838834 learning rate: 1.000000
# Minibatch perplexity: 5.76
# Validation set perplexity: 6.63
# Average loss at step 7000: 1.848802 learning rate: 1.000000
# Minibatch perplexity: 6.60
# ================================================================================
# uch those hemitshrain rerors conweems fram cobericull in cincii and elingle zone
# gvanivan puresting the even the linaucks the strampd flummi remelveud roneing the
# bted in the fhnettly corpheradistring as used one nine aried bownesion only thees
# zzers of the duinto wel the nine nine five five nine one one nine liver afrilites
# mdre reserved his welvated kingy elger wil bany world sia itsion in mearcee and c
# ================================================================================
# Validation set perplexity: 6.66

# %% [markdown]
# ---
# Problem 3
# ---------
#
# (difficult!)
#
# Write a sequence-to-sequence LSTM which mirrors all the words in a sentence. For example, if your input is:
#
#     the quick brown fox
#
# the model should attempt to output:
#
#     eht kciuq nworb xof
#
# Refer to the lecture on how to put together a sequence-to-sequence model, as well as [this article](http://arxiv.org/abs/1409.3215) for best practices.
#
# ---
