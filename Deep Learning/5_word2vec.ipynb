# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
from tensorflow.contrib.tensorboard.plugins import projector
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5238, 3082, 12, 6, 195, 2, 3135, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'a', 'originated', 'as', 'term', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['term', 'originated', 'anarchism', 'a', 'of', 'as', 'originated', 'term']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.659822
# Nearest to over: committed, bolo, psychotherapist, snippets, confidant, curule, asphalt, protectorates,
# Nearest to no: zork, leszek, dolmens, glasnevin, acknowledgement, ost, magadha, postures,
# Nearest to be: pergamon, multinational, fermi, decca, grim, benno, rosicrucians, insulation,
# Nearest to this: rature, career, tripartite, bordered, mycoplasma, copula, brisk, witty,
# Nearest to were: nora, angilbert, differentiability, oblique, nachrichten, arnaz, waff, fragmentary,
# Nearest to UNK: walkways, landmass, goodness, perpetrator, tumble, alkynes, gkos, bodybuilding,
# Nearest to was: reorganised, meanings, anxieties, rationals, photius, decreed, drury, justification,
# Nearest to nine: bastille, aulus, anecdotal, east, consultancy, muskegon, bitola, realising,
# Nearest to there: biot, westminster, arbitrary, miscarriage, saeed, archeologists, sniper, list,
# Nearest to which: bender, inducted, constantly, trypanosomiasis, reorganised, pronunciation, halos, perpetrators,
# Nearest to state: ababa, ghibli, grimm, legitimize, chile, suras, deuterostomes, kiang,
# Nearest to six: scrabble, familia, dtd, affords, mysore, camino, substitute, dorchester,
# Nearest to are: obp, deter, reiner, mana, unproductive, streak, pythagoreans, torment,
# Nearest to up: boudica, lilies, dysprosium, flea, interpretative, jutland, marrakech, hearse,
# Nearest to not: barbour, nonstandard, allah, impulse, mellows, zinc, mistakenly, devonport,
# Nearest to five: alone, gluons, roosevelt, absentia, chesapeake, shortest, jebel, wrappings,
# Average loss at step 2000: 4.371994
# Average loss at step 4000: 3.860985
# Average loss at step 6000: 3.790327
# Average loss at step 8000: 3.686500
# Average loss at step 10000: 3.616145
# Nearest to over: committed, bolo, cinnamon, confidant, my, penetrated, factbook, occasionally,
# Nearest to no: unimportant, unforeseen, zork, polyester, tables, leszek, mendelevium, natures,
# Nearest to be: have, smiling, is, was, regatta, subjects, led, by,
# Nearest to this: it, the, which, that, inserts, livonian, based, topographic,
# Nearest to were: are, was, oblique, nachrichten, waff, have, be, fortuitous,
# Nearest to UNK: gir, research, c, anthropomorphized, airstrips, landscapes, baths, interlisp,
# Nearest to was: is, were, had, has, by, are, succumbing, be,
# Nearest to nine: eight, seven, five, six, three, four, zero, two,
# Nearest to there: it, based, still, he, phosphorus, axons, westminster, sofie,
# Nearest to which: this, also, that, who, mond, hindering, it, suffering,
# Nearest to state: advertise, ababa, south, ghibli, albrecht, suras, specifications, gisela,
# Nearest to six: seven, eight, five, four, three, nine, zero, two,
# Nearest to are: were, is, was, have, nursery, plausibility, tragically, dedekind,
# Nearest to up: boudica, blinds, footballers, hauser, ending, shifter, malvaceae, lilies,
# Nearest to not: it, they, to, impulse, allah, also, stadt, safed,
# Nearest to five: eight, six, four, seven, three, nine, zero, two,
# Average loss at step 12000: 3.607249
# Average loss at step 14000: 3.579315
# Average loss at step 16000: 3.412120
# Average loss at step 18000: 3.462500
# Average loss at step 20000: 3.543249
# Nearest to over: committed, between, choices, penetrated, sahelian, about, cinnamon, shir,
# Nearest to no: unimportant, it, unforeseen, mendelevium, natures, zork, geophysical, scarred,
# Nearest to be: have, was, devotional, been, by, is, smiling, regatta,
# Nearest to this: it, which, the, inserts, any, that, jarre, its,
# Nearest to were: are, was, had, have, by, been, be, sz,
# Nearest to UNK: blavatsky, hine, wolfenstein, reinforced, charles, gir, rudolf, concerts,
# Nearest to was: is, were, has, had, be, became, succumbing, are,
# Nearest to nine: eight, six, seven, four, five, three, zero, two,
# Nearest to there: it, they, still, he, which, based, burden, but,
# Nearest to which: this, that, also, who, it, but, there, and,
# Nearest to state: suras, ghibli, albrecht, advertise, legislator, former, ceramics, debrecen,
# Nearest to six: seven, eight, four, nine, five, three, two, zero,
# Nearest to are: were, is, have, was, nursery, statistics, simplifications, be,
# Nearest to up: boudica, him, them, hauser, seamen, malvaceae, blinds, tacoma,
# Nearest to not: to, also, impulse, they, stadt, it, endured, now,
# Nearest to five: seven, three, four, six, eight, zero, two, nine,
# Average loss at step 22000: 3.503867
# Average loss at step 24000: 3.489861
# Average loss at step 26000: 3.480548
# Average loss at step 28000: 3.482434
# Average loss at step 30000: 3.500598
# Nearest to over: committed, between, tv, choices, sophistication, shir, penetrated, into,
# Nearest to no: unimportant, any, mendelevium, ling, natures, crtc, a, unforeseen,
# Nearest to be: have, been, devotional, is, were, inhalation, nominally, was,
# Nearest to this: which, it, that, what, inserts, jarre, samaritan, the,
# Nearest to were: are, was, have, had, been, be, by, is,
# Nearest to UNK: fraunhofer, hammond, gir, com, lovingly, grips, greeks, westernized,
# Nearest to was: is, had, has, were, been, became, by, being,
# Nearest to nine: eight, seven, six, four, five, three, zero, one,
# Nearest to there: they, it, still, he, now, usually, we, moog,
# Nearest to which: this, that, also, it, what, who, but, however,
# Nearest to state: ghibli, suras, legislator, albrecht, fry, states, advertise, specifications,
# Nearest to six: four, eight, seven, nine, five, three, two, zero,
# Nearest to are: were, is, have, hydropower, be, heterogeneous, statistics, olaf,
# Nearest to up: him, them, malvaceae, boudica, blinds, reach, hauser, atkins,
# Nearest to not: they, typically, still, tipu, now, it, there, also,
# Nearest to five: four, seven, six, eight, three, nine, zero, two,
# Average loss at step 32000: 3.497275
# Average loss at step 34000: 3.491812
# Average loss at step 36000: 3.448868
# Average loss at step 38000: 3.300632
# Average loss at step 40000: 3.430564
# Nearest to over: between, committed, about, choices, across, through, tv, builders,
# Nearest to no: any, unimportant, crtc, unforeseen, a, ling, than, mendelevium,
# Nearest to be: have, been, devotional, was, being, regatta, by, donned,
# Nearest to this: which, it, that, the, what, he, any, lipstick,
# Nearest to were: are, have, had, was, vicious, been, sz, be,
# Nearest to UNK: le, emil, d, peter, charles, ma, vocalist, robert,
# Nearest to was: is, had, became, has, been, were, be, solidified,
# Nearest to nine: eight, seven, six, five, four, zero, three, two,
# Nearest to there: they, it, still, he, now, usually, she, which,
# Nearest to which: that, this, also, it, who, what, there, however,
# Nearest to state: government, suras, albrecht, former, states, legislator, proponents, turbojet,
# Nearest to six: four, five, seven, eight, nine, two, three, zero,
# Nearest to are: were, is, have, be, hydropower, although, sz, these,
# Nearest to up: them, him, malvaceae, out, reach, cosmetics, blinds, boudica,
# Nearest to not: still, now, typically, they, it, unifies, mistakenly, also,
# Nearest to five: six, seven, four, three, zero, nine, eight, two,
# Average loss at step 42000: 3.436489
# Average loss at step 44000: 3.452074
# Average loss at step 46000: 3.448809
# Average loss at step 48000: 3.352521
# Average loss at step 50000: 3.382648
# Nearest to over: through, between, committed, across, choices, about, off, mingus,
# Nearest to no: any, unimportant, unforeseen, crtc, viscous, easily, cantatas, microfluidics,
# Nearest to be: have, devotional, been, are, become, donned, was, being,
# Nearest to this: which, it, the, lipstick, that, some, what, tezuka,
# Nearest to were: are, have, was, be, had, vicious, been, remain,
# Nearest to UNK: http, fevers, mathew, maia, civitas, der, jehoshaphat, leafy,
# Nearest to was: is, has, were, became, had, been, be, by,
# Nearest to nine: eight, seven, six, four, five, three, zero, two,
# Nearest to there: they, it, still, he, she, now, usually, who,
# Nearest to which: that, this, also, who, what, often, it, however,
# Nearest to state: government, states, suras, albrecht, legislator, former, cosmological, proponents,
# Nearest to six: eight, seven, four, nine, five, three, two, one,
# Nearest to are: were, is, have, be, sz, those, was, stardust,
# Nearest to up: them, out, him, me, off, together, down, back,
# Nearest to not: now, still, tipu, generally, typically, unifies, backfire, they,
# Nearest to five: four, six, seven, eight, three, nine, zero, two,
# Average loss at step 52000: 3.436335
# Average loss at step 54000: 3.428403
# Average loss at step 56000: 3.441726
# Average loss at step 58000: 3.396876
# Average loss at step 60000: 3.397480
# Nearest to over: through, between, across, committed, choices, about, off, into,
# Nearest to no: any, unimportant, viscous, little, unforeseen, ling, cantatas, crtc,
# Nearest to be: been, devotional, become, have, was, find, donned, provide,
# Nearest to this: which, it, that, there, what, however, the, some,
# Nearest to were: are, was, been, had, have, vicious, remain, sura,
# Nearest to UNK: genuine, crichton, absurdity, gir, cplp, priscilla, nod, shiragami,
# Nearest to was: is, had, were, became, been, has, solidified, be,
# Nearest to nine: eight, six, seven, four, five, three, zero, one,
# Nearest to there: they, it, still, now, she, he, we, often,
# Nearest to which: that, this, what, however, but, who, it, these,
# Nearest to state: government, states, former, xt, turbojet, concept, suras, constitution,
# Nearest to six: four, eight, five, nine, seven, three, zero, two,
# Nearest to are: were, is, have, although, differentiable, be, been, include,
# Nearest to up: them, him, out, off, down, together, close, back,
# Nearest to not: still, now, to, tipu, typically, they, unifies, kampong,
# Nearest to five: six, four, three, eight, seven, nine, zero, two,
# Average loss at step 62000: 3.245041
# Average loss at step 64000: 3.251637
# Average loss at step 66000: 3.404218
# Average loss at step 68000: 3.396444
# Average loss at step 70000: 3.355615
# Nearest to over: across, about, choices, committed, between, through, off, choctaws,
# Nearest to no: any, viscous, little, unimportant, there, microfluidics, unforeseen, halas,
# Nearest to be: been, become, is, devotional, have, being, were, was,
# Nearest to this: which, it, the, that, what, munda, lipstick, another,
# Nearest to were: are, was, have, had, been, be, remain, sura,
# Nearest to UNK: installed, hine, concerts, heisenberg, conversely, janet, dyck, leans,
# Nearest to was: is, has, had, were, became, been, solidified, be,
# Nearest to nine: eight, seven, six, four, five, three, zero, one,
# Nearest to there: they, it, still, he, now, often, she, we,
# Nearest to which: that, this, also, but, what, however, it, ktav,
# Nearest to state: government, states, former, city, constitution, department, placeholder, cosmological,
# Nearest to six: four, seven, five, eight, nine, three, two, zero,
# Nearest to are: were, is, have, while, although, include, stein, differentiable,
# Nearest to up: them, out, down, him, off, back, close, me,
# Nearest to not: now, still, typically, kampong, generally, unifies, tipu, usually,
# Nearest to five: six, four, three, seven, eight, zero, nine, two,
# Average loss at step 72000: 3.375958
# Average loss at step 74000: 3.346141
# Average loss at step 76000: 3.317145
# Average loss at step 78000: 3.349067
# Average loss at step 80000: 3.379340
# Nearest to over: across, between, about, off, around, before, through, choices,
# Nearest to no: any, little, unforeseen, unimportant, natures, there, viscous, figurehead,
# Nearest to be: been, have, being, become, devotional, are, was, is,
# Nearest to this: which, it, the, lipstick, what, another, munda, some,
# Nearest to were: are, had, was, have, been, became, remain, those,
# Nearest to UNK: saint, underwood, http, amhr, gujarati, lachaise, enraged, maluku,
# Nearest to was: is, became, had, were, has, been, be, aglaulus,
# Nearest to nine: eight, seven, six, five, four, three, zero, pmid,
# Nearest to there: it, they, still, he, she, we, often, now,
# Nearest to which: this, that, what, it, usually, based, but, who,
# Nearest to state: government, city, states, fry, albrecht, colleges, constitution, afonso,
# Nearest to six: four, five, eight, seven, three, nine, two, one,
# Nearest to are: were, have, is, include, although, be, perforated, these,
# Nearest to up: out, them, off, down, him, together, close, back,
# Nearest to not: still, now, typically, usually, generally, unifies, often, actually,
# Nearest to five: six, four, eight, seven, three, nine, zero, two,
# Average loss at step 82000: 3.408811
# Average loss at step 84000: 3.409583
# Average loss at step 86000: 3.389673
# Average loss at step 88000: 3.348576
# Average loss at step 90000: 3.364779
# Nearest to over: off, around, across, through, about, before, between, choices,
# Nearest to no: any, little, unimportant, easily, ascalon, previously, natures, there,
# Nearest to be: been, was, devotional, is, become, being, have, easily,
# Nearest to this: which, it, some, the, lipstick, another, what, lindsay,
# Nearest to were: are, had, was, have, while, sura, those, remain,
# Nearest to UNK: environmentally, http, fanbase, etymologies, pat, gir, eds, walsh,
# Nearest to was: is, had, were, became, has, be, been, being,
# Nearest to nine: eight, seven, six, five, four, zero, three, one,
# Nearest to there: they, it, still, he, she, we, now, often,
# Nearest to which: this, that, what, also, usually, it, who, validly,
# Nearest to state: city, government, states, fry, outfit, albrecht, friars, afonso,
# Nearest to six: seven, eight, four, five, nine, three, two, zero,
# Nearest to are: were, is, include, have, these, although, remain, sz,
# Nearest to up: out, off, down, them, together, back, him, thx,
# Nearest to not: still, now, unifies, nor, mistakenly, also, usually, generally,
# Nearest to five: four, eight, seven, six, three, nine, zero, two,
# Average loss at step 92000: 3.397934
# Average loss at step 94000: 3.257068
# Average loss at step 96000: 3.357240
# Average loss at step 98000: 3.244037
# Average loss at step 100000: 3.354732
# Nearest to over: across, between, about, off, around, through, cheltenham, choices,
# Nearest to no: any, little, ascalon, unforeseen, irrationality, beauharnais, unimportant, epiphanius,
# Nearest to be: been, have, become, were, are, devotional, was, is,
# Nearest to this: which, it, he, some, another, what, gh, itself,
# Nearest to were: are, was, have, be, had, these, been, although,
# Nearest to UNK: lachaise, spectacled, luis, fernando, nucleic, indium, huntington, autonomously,
# Nearest to was: is, were, became, been, had, has, being, be,
# Nearest to nine: eight, seven, six, four, five, zero, three, pmid,
# Nearest to there: they, still, it, he, we, now, she, often,
# Nearest to which: that, this, usually, what, actually, it, neuromuscular, however,
# Nearest to state: government, city, states, fry, loco, afonso, friars, outfit,
# Nearest to six: four, seven, five, eight, nine, two, three, zero,
# Nearest to are: were, have, be, is, remain, although, include, while,
# Nearest to up: out, together, off, down, back, them, him, thx,
# Nearest to not: now, still, they, nor, almost, never, generally, unifies,
# Nearest to five: seven, six, four, eight, three, nine, zero, two,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %% [markdown]
# ## Continuous bag of words
# Similar to the Skip gram, but instead of the adjacent words being targets given a single word, the single word is the target given the sum of adjacent words.

# %%
data_index = 0

def generate_batch(batch_size, bag_window):
  global data_index
  span = 2 * bag_window + 1 # [ bag_window target bag_window ]
  batch = np.ndarray(shape=(batch_size, span - 1), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size):
    buffer_list = list(buffer)
    labels[i, 0] = buffer_list.pop(bag_window)
    batch[i] = buffer_list
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for bag_window in (2, 1):
    data_index = 0
    batch, labels = generate_batch(batch_size=8, bag_window=bag_window)
    print('\nwith bag_window = %d:' % (bag_window))
    print('    batch:', [[reverse_dictionary[w] for w in bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with bag_window = 2:
#     batch: [['anarchism', 'originated', 'a', 'term'], ['originated', 'as', 'term', 'of'], ['as', 'a', 'of', 'abuse'], ['a', 'term', 'abuse', 'first'], ['term', 'of', 'first', 'used'], ['of', 'abuse', 'used', 'against'], ['abuse', 'first', 'against', 'early'], ['first', 'used', 'early', 'working']]
#     labels: ['as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against']
#
# with bag_window = 1:
#     batch: [['anarchism', 'as'], ['originated', 'a'], ['as', 'term'], ['a', 'of'], ['term', 'abuse'], ['of', 'first'], ['abuse', 'used'], ['first', 'against']]
#     labels: ['originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used']

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
bag_window = 2 # How many words to consider left and right.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size, bag_window * 2])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embeds = tf.nn.embedding_lookup(embeddings, train_dataset)
  #Note embed is the embedding for all he train dataset words, not just one word like in skip gram
  # Compute the softmax loss, using a sample of the negative labels each time.
  #Note, the input is the sum of all the embeddings
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=tf.reduce_sum(embeds, 1),
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, bag_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.135355
# Nearest to up: tomorrowland, heresy, promo, eligibility, biotic, cantata, blockage, deformity,
# Nearest to between: norwegians, civic, translating, suffragan, sticker, glacial, iranians, soto,
# Nearest to UNK: minorca, anxiolytic, naturalist, manga, adriaan, storytelling, phonation, mishandling,
# Nearest to of: bithynia, kasner, nicolay, lots, bantu, clyde, mister, kinks,
# Nearest to it: hermeneutics, capillary, duets, coo, liga, sumerian, swordsmen, elway,
# Nearest to into: tumbling, corsairs, touring, polydor, mir, neptunian, bleed, router,
# Nearest to over: seraphim, ecclesiastical, substantially, fief, ives, gadolinium, zaire, synergies,
# Nearest to about: alle, botanicals, hilton, stabilization, polishing, linton, misnomer, stabilizer,
# Nearest to for: sweetened, jungian, crafted, tours, uprooted, complex, fiat, designs,
# Nearest to american: robert, grooming, shown, rest, scriptorium, donn, spaces, anesthesia,
# Nearest to some: quito, cancelled, recoveries, competences, telomeres, astrophysicists, adv, fifteen,
# Nearest to zero: governmental, jour, fraternal, promulgate, cubic, bhagavad, external, flunitrazepam,
# Nearest to a: incredibly, hannity, vigesimal, borg, kat, insulator, aegon, hellenized,
# Nearest to there: orators, recipient, raman, quaternary, antwerp, tend, hasan, vo,
# Nearest to use: unilaterally, carry, farouk, archived, yeomen, breaded, stubborn, alfaro,
# Nearest to more: okeh, moritz, yank, baez, nitrous, novum, to, hepatitis,
# Average loss at step 2000: 4.605910
# Average loss at step 4000: 3.931802
# Average loss at step 6000: 3.723383
# Average loss at step 8000: 3.526114
# Average loss at step 10000: 3.475576
# Nearest to up: biotic, them, morph, typologically, platters, pundit, heresy, tomorrowland,
# Nearest to between: suzuki, glockenspiel, pilgrimage, guido, recension, rhetorician, lcms, amistad,
# Nearest to UNK: borgia, authorizes, quirks, rocker, kanembu, blacksmith, mandarin, altar,
# Nearest to of: for, bithynia, mayors, roaming, cabbage, under, ousted, including,
# Nearest to it: he, this, there, they, cops, motherhood, fundraising, perishable,
# Nearest to into: from, coconuts, polydor, transshipment, fairly, traded, fielder, dara,
# Nearest to over: xl, bowmen, convent, formed, won, discreet, comprehension, gladiator,
# Nearest to about: stimulants, walkways, scarce, piled, bunch, endl, sextet, industrious,
# Nearest to for: of, with, additionally, until, delaney, halogen, cameron, shelton,
# Nearest to american: canadian, shirts, cummings, malinche, overrides, loyola, ergonomic, gradually,
# Nearest to some: many, several, these, any, inca, various, the, other,
# Nearest to zero: five, eight, nine, six, seven, four, three, two,
# Nearest to a: any, the, another, an, no, borg, this, machen,
# Nearest to there: it, they, these, favored, prefectural, bebop, caius, orators,
# Nearest to use: cheaply, birth, expressways, pianos, cause, mean, superposition, nowhere,
# Nearest to more: less, rather, greater, most, other, munk, erroneously, evolutionism,
# Average loss at step 12000: 3.485199
# Average loss at step 14000: 3.440121
# Average loss at step 16000: 3.435057
# Average loss at step 18000: 3.394343
# Average loss at step 20000: 3.208966
# Nearest to up: out, biotic, him, them, accountants, consulate, fetch, typologically,
# Nearest to between: on, pilgrimage, crystallographic, near, luxembourg, into, within, with,
# Nearest to UNK: d, canadian, indeterminate, van, mandarin, levi, sardinia, paul,
# Nearest to of: while, roaming, justly, umno, subverted, since, for, bithynia,
# Nearest to it: he, she, there, this, they, skies, actually, coretta,
# Nearest to into: from, psychiatrists, pc, through, retroviruses, removing, between, criss,
# Nearest to over: through, morgue, tidewater, turnbull, xl, downloaded, fictionalised, loran,
# Nearest to about: scarce, videogames, on, cadmium, airfields, phnom, downstream, missy,
# Nearest to for: fiat, uncle, faq, horrors, injector, additionally, halogen, of,
# Nearest to american: s, canadian, mariano, grows, shorty, unravel, mixolydian, prepubescent,
# Nearest to some: many, various, several, these, both, any, most, maxime,
# Nearest to zero: seven, five, eight, six, three, nine, four, two,
# Nearest to a: another, the, an, any, pell, borg, every, laborer,
# Nearest to there: it, they, longer, these, faltering, rgya, considered, used,
# Nearest to use: refers, revivalist, monrovia, nirvana, form, skit, craving, amount,
# Nearest to more: less, rather, most, greater, very, other, better, donn,
# Average loss at step 22000: 3.355425
# Average loss at step 24000: 3.292049
# Average loss at step 26000: 3.263923
# Average loss at step 28000: 3.280464
# Average loss at step 30000: 3.229394
# Nearest to up: off, out, biotic, consulate, them, holes, accountants, cameroonian,
# Nearest to between: with, into, groundbreaking, pilgrimage, within, intermediates, kalamazoo, apostate,
# Nearest to UNK: earthdawn, de, refrigerant, vapor, kenneth, lun, mus, listeners,
# Nearest to of: during, in, among, ung, roaming, since, bithynia, ousted,
# Nearest to it: he, she, this, there, qam, handicraft, now, ammianus,
# Nearest to into: through, from, around, between, psychiatrists, within, cheese, removing,
# Nearest to over: through, before, polymers, turnbull, downloaded, glockenspiel, around, submissive,
# Nearest to about: mmc, on, before, scarce, excluding, around, hilberg, hermetic,
# Nearest to for: after, through, despite, injector, hierarchies, interactively, uncle, jstor,
# Nearest to american: zelaya, orator, sacramento, antarctic, british, ong, international, eliminates,
# Nearest to some: many, several, various, all, numerous, most, both, those,
# Nearest to zero: five, nine, six, eight, seven, four, three, th,
# Nearest to a: the, another, wry, any, oases, an, machen, every,
# Nearest to there: they, it, longer, she, rgya, faltering, adalbert, considered,
# Nearest to use: support, revivalist, form, monrovia, amount, showings, refers, seamlessly,
# Nearest to more: less, rather, better, greater, very, too, munk, donn,
# Average loss at step 32000: 3.006412
# Average loss at step 34000: 3.207188
# Average loss at step 36000: 3.195136
# Average loss at step 38000: 3.159978
# Average loss at step 40000: 3.170182
# Nearest to up: out, off, him, prosecuted, accountants, tradesmen, kaj, biotic,
# Nearest to between: within, with, into, in, through, galway, judas, pilgrimage,
# Nearest to UNK: actium, kenneth, etsi, xxvii, overture, delicate, din, christadelphians,
# Nearest to of: roaming, within, nephropathy, in, ung, bithynia, including, throughout,
# Nearest to it: he, she, this, there, sometimes, sandy, mnism, investiture,
# Nearest to into: through, within, from, across, out, psychiatrists, down, between,
# Nearest to over: through, under, downloaded, around, heston, about, at, leda,
# Nearest to about: over, cadmium, around, gms, hilberg, obituary, scarce, beaverbrook,
# Nearest to for: seventeen, including, after, hallucination, injector, despite, rejuvenation, stilicho,
# Nearest to american: america, canadian, british, atlantic, individual, jiao, indian, orator,
# Nearest to some: many, several, various, both, showa, multiple, numerous, most,
# Nearest to zero: four, eight, five, six, seven, three, nine, two,
# Nearest to a: another, the, every, any, osborne, an, kenyatta, machen,
# Nearest to there: longer, considered, it, called, faltering, rgya, she, konya,
# Nearest to use: because, support, type, apply, sense, form, list, incentive,
# Nearest to more: less, rather, very, better, quite, most, greater, smaller,
# Average loss at step 42000: 3.212210
# Average loss at step 44000: 3.137584
# Average loss at step 46000: 3.153062
# Average loss at step 48000: 3.060353
# Average loss at step 50000: 3.059847
# Nearest to up: off, out, cameroonian, him, tradesmen, down, together, rocky,
# Nearest to between: with, into, motorola, among, examinations, trafalgar, denethor, judas,
# Nearest to UNK: pigpen, ko, g, macht, alex, nicholls, sewage, telepathic,
# Nearest to of: including, nephropathy, bithynia, lonsdale, following, for, contains, vortigern,
# Nearest to it: he, she, this, there, agnesi, qam, solvents, snl,
# Nearest to into: within, through, from, around, across, between, in, out,
# Nearest to over: around, under, against, at, supremacist, into, through, steed,
# Nearest to about: on, around, scarce, virtuosity, regarding, hilberg, into, undetected,
# Nearest to for: including, trades, jstor, without, hierarchies, homology, changeable, accumulator,
# Nearest to american: british, canadian, propagation, japanese, overrides, ong, straddles, brazilian,
# Nearest to some: many, several, various, certain, numerous, all, any, these,
# Nearest to zero: eight, five, seven, nine, four, three, six, million,
# Nearest to a: any, the, another, wry, machen, borg, flint, osborne,
# Nearest to there: they, longer, it, considered, still, dysprosium, neoconservative, he,
# Nearest to use: support, usage, cerebrum, benefit, treatment, used, minotaurs, nerva,
# Nearest to more: less, rather, most, quite, very, better, too, greater,
# Average loss at step 52000: 3.095695
# Average loss at step 54000: 3.097629
# Average loss at step 56000: 2.915111
# Average loss at step 58000: 3.014868
# Average loss at step 60000: 3.041622
# Nearest to up: off, out, him, down, tradesmen, unbound, fk, indispensable,
# Nearest to between: with, among, through, endo, across, thus, judas, into,
# Nearest to UNK: earthdawn, de, cagliari, toc, mutants, yvonne, reprisal, plural,
# Nearest to of: roaming, lonsdale, however, fortunate, celera, cousteau, including, changeable,
# Nearest to it: he, this, she, there, cardiology, which, agnesi, what,
# Nearest to into: through, within, across, onto, over, from, nagel, psychiatrists,
# Nearest to over: through, during, into, glover, against, under, throughout, around,
# Nearest to about: on, virtuosity, regarding, around, concerning, hilberg, mere, mitterrand,
# Nearest to for: interactively, toward, veal, attractors, rejuvenation, without, adenylate, shelton,
# Nearest to american: canadian, indian, america, british, australian, mikael, italian, international,
# Nearest to some: many, several, various, certain, all, numerous, most, multiple,
# Nearest to zero: five, eight, six, four, three, seven, nine, million,
# Nearest to a: another, any, the, every, no, an, machen, iskra,
# Nearest to there: longer, they, it, called, cheung, named, slanted, treated,
# Nearest to use: apply, clemency, usage, support, produce, cerebrum, addition, taganrog,
# Nearest to more: less, rather, better, greater, most, quite, longer, highly,
# Average loss at step 62000: 3.017468
# Average loss at step 64000: 2.925417
# Average loss at step 66000: 2.931881
# Average loss at step 68000: 2.955364
# Average loss at step 70000: 3.013945
# Nearest to up: off, out, down, together, maha, cameroonian, tradesmen, him,
# Nearest to between: among, with, across, through, within, into, endo, betray,
# Nearest to UNK: harrison, kom, mortem, sakai, dispatches, essayists, larp, po,
# Nearest to of: including, for, roaming, nephropathy, despite, fledging, bithynia, during,
# Nearest to it: he, she, cream, this, there, harnessed, disloyal, annette,
# Nearest to into: through, within, from, across, onto, over, on, psychiatrists,
# Nearest to over: through, during, into, markup, pooled, throughout, under, glover,
# Nearest to about: on, concerning, regarding, fallacies, around, over, main, impiety,
# Nearest to for: veal, of, seventeen, without, shelton, injector, despite, after,
# Nearest to american: canadian, british, australian, thummim, international, england, bridle, america,
# Nearest to some: many, several, certain, various, numerous, all, both, these,
# Nearest to zero: five, eight, two, seven, six, three, nine, larps,
# Nearest to a: another, the, any, every, machen, hinayana, oases, this,
# Nearest to there: longer, still, faltering, they, slanted, receded, iras, considered,
# Nearest to use: consist, version, bihari, apply, benefit, pelt, usage, admit,
# Nearest to more: less, quite, better, very, too, most, faster, greater,
# Average loss at step 72000: 2.937789
# Average loss at step 74000: 2.863752
# Average loss at step 76000: 2.999648
# Average loss at step 78000: 3.008970
# Average loss at step 80000: 2.843734
# Nearest to up: off, out, down, him, together, morph, encyclopaedia, holes,
# Nearest to between: with, among, across, pilgrimage, endo, trafalgar, motorola, within,
# Nearest to UNK: din, emory, r, ko, tallinn, ba, carving, ais,
# Nearest to of: following, locusts, including, changeable, nephropathy, mcs, inspirational, behind,
# Nearest to it: he, she, this, there, ascending, itself, cardiology, today,
# Nearest to into: through, across, onto, within, from, beyond, psychiatrists, polydor,
# Nearest to over: around, through, lamorna, during, throughout, off, almost, maison,
# Nearest to about: concerning, on, guerillas, regarding, into, main, phnom, sweyn,
# Nearest to for: veal, shelton, rejuvenation, iudex, homology, injector, attractors, seventeen,
# Nearest to american: america, canadian, indian, australian, british, italian, independent, community,
# Nearest to some: many, several, certain, various, most, both, all, numerous,
# Nearest to zero: eight, seven, five, six, nine, four, three, two,
# Nearest to a: another, the, any, every, machen, this, flint, each,
# Nearest to there: longer, they, it, he, still, she, contestants, galloway,
# Nearest to use: consist, addition, form, support, cause, apply, because, bihari,
# Nearest to more: less, rather, very, quite, most, better, worse, greater,
# Average loss at step 82000: 2.943333
# Average loss at step 84000: 2.903089
# Average loss at step 86000: 2.917047
# Average loss at step 88000: 2.942945
# Average loss at step 90000: 2.830431
# Nearest to up: off, down, out, together, back, forth, holes, unbound,
# Nearest to between: with, across, therefore, among, into, endo, throughout, from,
# Nearest to UNK: manar, l, racially, na, heather, ndp, petitioner, sauce,
# Nearest to of: including, in, nephropathy, ung, roaming, following, appended, for,
# Nearest to it: he, she, this, there, perishable, they, everyone, sai,
# Nearest to into: through, across, onto, within, beyond, from, around, together,
# Nearest to over: around, through, during, throughout, across, down, off, about,
# Nearest to about: concerning, guerillas, dethroned, regarding, over, phnom, lets, on,
# Nearest to for: after, seventeen, springer, allomorphy, paradiso, of, shelton, interactively,
# Nearest to american: australian, america, british, indian, canadian, african, horror, atlantic,
# Nearest to some: many, various, several, numerous, most, certain, multiple, both,
# Nearest to zero: five, four, six, seven, nine, three, two, eight,
# Nearest to a: another, any, the, every, machen, this, oases, roasted,
# Nearest to there: they, longer, it, she, faltering, called, still, considered,
# Nearest to use: consist, form, uses, produce, share, apply, play, incentive,
# Nearest to more: less, rather, better, most, quite, highly, fewer, greater,
# Average loss at step 92000: 2.901296
# Average loss at step 94000: 2.889112
# Average loss at step 96000: 2.710863
# Average loss at step 98000: 2.459947
# Average loss at step 100000: 2.709335
# Nearest to up: off, out, together, down, forth, holes, directing, minivan,
# Nearest to between: among, with, across, thus, through, within, into, pilgrimage,
# Nearest to UNK: macht, gly, rocker, girl, ennis, postcard, cyclones, ne,
# Nearest to of: roaming, nephropathy, changeable, in, represents, including, ung, budgeted,
# Nearest to it: she, he, there, espace, this, now, perishable, everyone,
# Nearest to into: through, across, onto, down, within, beyond, together, in,
# Nearest to over: through, down, around, off, during, throughout, across, submissive,
# Nearest to about: concerning, lets, regarding, on, ancillary, into, phnom, around,
# Nearest to for: after, despite, injector, without, during, additionally, through, interactively,
# Nearest to american: english, canadian, australian, british, irish, overrides, scottish, italian,
# Nearest to some: many, several, various, numerous, certain, both, all, this,
# Nearest to zero: five, eight, four, six, seven, nine, three, two,
# Nearest to a: another, any, the, machen, no, every, iskra, irt,
# Nearest to there: they, it, faltering, she, you, still, longer, debacle,
# Nearest to use: support, form, apply, speak, produce, consist, version, incentive,
# Nearest to more: less, better, rather, faster, fewer, worse, larger, stronger,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# # Try creating the model in a class

# %%
#All changeable parameters for the model

batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
bag_window = 2 # How many words to consider left and right.
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.
learning_rate = 1.0

# %%
# Create the class for bag of words model

class BagOfWords:
    """ Build the graph for word2vec model """
    global train_dataset
    def __init__(self, valid_size, valid_window, vocabulary_size, valid_examples, embedding_size, batch_size, bag_window, num_sampled):
        self.valid_size = valid_size
        self.valid_window = valid_window
        self.valid_examples = valid_examples
        self.vocabulary_size = vocabulary_size
        self.embedding_size = embedding_size
        self.batch_size = batch_size
        self.bag_window = bag_window
        self.num_sampled = num_sampled
        self.learning_rate = learning_rate
        self.global_step = tf.Variable(0, dtype=tf.int32, trainable=False, name='global_step')
        
##    def _create_placeholders(self):
##       """ Step 1: define the placeholders for input and output """
##      with tf.name_scope("data"):
##         self.train_dataset = tf.placeholder(tf.int32, shape=[self.batch_size, self.bag_window * 2], name='train_dataset')
##        self.train_labels = tf.placeholder(tf.int32, shape=[self.batch_size, 1], name='train_labels')
##       self.valid_dataset = tf.constant(self.valid_examples, dtype=tf.int32, name='valid_dataset')

    def _create_embedding(self):
        """ Step 2: define weights. In word2vec, it's actually the weights that we care about """
        
        with tf.name_scope("embed"):
            self.embeddings = tf.Variable(
                            tf.random_uniform([self.vocabulary_size, self.embedding_size], -1.0, 1.0), name='embeddings')

    def _create_loss(self):
        """ Step 3 + 4: define the model + the loss function """
        with tf.name_scope("loss"):
            softmax_weights = tf.Variable(tf.truncated_normal([self.vocabulary_size, self.embedding_size],
                             stddev=1.0 / math.sqrt(self.embedding_size)), name='softmax_weights')
            
            softmax_biases = tf.Variable(tf.zeros([self.vocabulary_size]), name='softmax_biases')
            
            # Model.
            # Look up embeddings for inputs.
            embeds = tf.nn.embedding_lookup(self.embeddings, self.train_dataset, name='embeds')
            #Note embed is the embedding for all he train dataset words, not just one word like in skip gram
            # Compute the softmax loss, using a sample of the negative labels each time.
            #Note, the input is the sum of all the embeddings
            self.loss = tf.reduce_mean(
                tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=tf.reduce_sum(embeds, 1),
                               labels=self.train_labels, num_sampled=self.num_sampled, num_classes=self.vocabulary_size), name='loss')
            
    def _create_optimizer(self):
        """ Step 5: define optimizer """
        self.optimizer = tf.train.AdagradOptimizer(self.learning_rate).minimize(self.loss, global_step=self.global_step)
        # Compute the similarity between minibatch examples and all embeddings.
        # We use the cosine distance:
        norm = tf.sqrt(tf.reduce_sum(tf.square(self.embeddings), 1, keep_dims=True))
        self.normalized_embeddings = self.embeddings / norm
        self.valid_embeddings = tf.nn.embedding_lookup(
            self.normalized_embeddings, self.valid_dataset)
        self.similarity = tf.matmul(self.valid_embeddings, tf.transpose(self.normalized_embeddings))
    
    def _create_summaries(self):
        with tf.name_scope("summaries"):
            tf.summary.scalar("loss", self.loss)
            tf.summary.histogram("histogram_loss", self.loss)
            # because you have several summaries, we should merge them all
            # into one op to make it easier to manage
            self.summary_op = tf.summary.merge_all()
            
    def build_graph(self):
        """ Build the graph for our model """
        self._create_embedding()
        self._create_loss()
        self._create_optimizer()
        self._create_summaries()

# %%
def make_dir(path):
    """ Create a directory if there isn't one already. """
    try:
        os.mkdir(path)
    except OSError:
        pass

# %%
data_index = 0

def generate_batch(batch_size, bag_window):
  global data_index
  span = 2 * bag_window + 1 # [ bag_window target bag_window ]
  batch = np.ndarray(shape=(batch_size, span - 1), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size):
    buffer_list = list(buffer)
    labels[i, 0] = buffer_list.pop(bag_window)
    batch[i] = buffer_list
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

# %%
""" Step 1: define the placeholders for input and output """
with tf.name_scope("data"):
    train_dataset = tf.placeholder(tf.int32, shape=[batch_size, bag_window * 2], name='train_dataset')
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1], name='train_labels')
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32, name='valid_dataset')


num_steps = 100001

def train_model(model, num_steps, batch_size, bag_window):
    saver = tf.train.Saver() # defaults to saving all variables
    
    initial_step = 0
    
    make_dir('checkpoints')
    
    with tf.Session() as sess:
        sess.run(tf.global_variables_initializer())
        ckpt = tf.train.get_checkpoint_state(os.path.dirname('checkpoints/checkpoint'))
        # if that checkpoint exists, restore from checkpoint
        if ckpt and ckpt.model_checkpoint_path:
            saver.restore(sess, ckpt.model_checkpoint_path)
        
        average_loss = 0
        
        writer = tf.summary.FileWriter('improved_graph/lr' + str(learning_rate), sess.graph)
        initial_step = model.global_step.eval()
        
        for step in range(initial_step, initial_step + num_steps):
            batch_data, batch_labels = generate_batch(batch_size, bag_window)
            tf.summary.scalar("loss", model.loss)
            tf.summary.histogram("histogram_loss", model.loss)
            # because you have several summaries, we should merge them all
            # into one op to make it easier to manage
            summary_op = tf.summary.merge_all()        
            feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
            l, _, summary = sess.run([model.loss, model.optimizer, summary_op], feed_dict=feed_dict)
            average_loss += l

            
            writer.add_summary(summary, global_step=step)
            if step % 2000 == 0:
                if step > 0:
                    average_loss = average_loss / 2000
                    # The average loss is an estimate of the loss over the last 2000 batches.
                    print('Average loss at step %d: %f' % (step, average_loss))
                    average_loss = 0
            # note that this is expensive (~20% slowdown if computed every 500 steps)
            if step % 10000 == 0:
                sim = model.similarity.eval()
                for i in range(valid_size):
                    valid_word = reverse_dictionary[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = reverse_dictionary[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                print(log)
                saver.save(sess, 'checkpoints/skip-gram', index)

# %%
model = BagOfWords(valid_size=valid_size, valid_window=valid_window,
                   vocabulary_size=vocabulary_size, valid_examples=valid_examples,
                   embedding_size=embedding_size, batch_size=batch_size, bag_window=bag_window,
                   num_sampled=num_sampled)
model.build_graph()
train_model(model=model, num_steps=num_steps, batch_size=batch_size, bag_window=bag_window)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-28-f404c06c5ab9> in <module>()
#       3                    embedding_size=embedding_size, batch_size=batch_size, bag_window=bag_window,
#       4                    num_sampled=num_sampled)
# ----> 5 model.build_graph()
#       6 train_model(model=model, num_steps=num_steps, batch_size=batch_size, bag_window=bag_window)
#
# <ipython-input-24-ff60c265659c> in build_graph(self)
#      70         """ Build the graph for our model """
#      71         self._create_embedding()
# ---> 72         self._create_loss()
#      73         self._create_optimizer()
#      74         self._create_summaries()
#
# <ipython-input-24-ff60c265659c> in _create_loss(self)
#      40             # Model.
#      41             # Look up embeddings for inputs.
# ---> 42             embeds = tf.nn.embedding_lookup(self.embeddings, self.train_dataset, name='embeds')
#      43             #Note embed is the embedding for all he train dataset words, not just one word like in skip gram
#      44             # Compute the softmax loss, using a sample of the negative labels each time.
#
# AttributeError: 'BagOfWords' object has no attribute 'train_dataset'
